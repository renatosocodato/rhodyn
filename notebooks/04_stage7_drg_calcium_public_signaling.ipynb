# %% [markdown]
# # Stage 7.3 DRG calcium public signaling demonstration
#
# This notebook reads the retained Stage 7.3 outputs. It does not download raw public source files.

# %%
from pathlib import Path
import pandas as pd
root = Path("..")
stage = root / "case_studies" / "stage7_public_signaling"
summary = pd.read_csv(stage / "drg_calcium_residence_amplitude_summary.csv")
summary["amplitude_residence_class"].value_counts()

# %%
traj = pd.read_csv(stage / "drg_calcium_tidy_trajectories.csv")
traj[["condition", "cell_id", "time", "signal", "mouse"]].head()

# %%
pd.read_csv(stage / "drg_calcium_uncertainty_summary.csv")
