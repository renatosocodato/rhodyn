# %% [markdown]
# # Stage 7.4 endpoint, reserve-like, and routed-output demonstrations
#
# This notebook reads retained Stage 7.4 outputs. It does not download raw public source files.

# %%
from pathlib import Path
import csv, json
root = Path('case_studies/stage7_endpoint_reserve_routing')
gate = json.loads((root / 'stage7_4_endpoint_reserve_routing_gate_report.json').read_text())
gate['status'], gate['selected_cases']

# %%
with (root / 'cell_painting_routed_model_comparison.csv').open(newline='') as handle:
    ranking = list(csv.DictReader(handle))
ranking[:3]

# %%
with (root / 'cell_painting_reserve_like_uncertainty.csv').open(newline='') as handle:
    reserve_uncertainty = list(csv.DictReader(handle))
reserve_uncertainty

# %%
with (root / 'erk_akt_bounded_coupling_decisions.csv').open(newline='') as handle:
    coupling = list(csv.DictReader(handle))
[(row['ligand'], row['claim_status'], row['margin']) for row in coupling]
